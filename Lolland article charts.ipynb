# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
font = {'size': 16}
matplotlib.rc('font', **font)
markersize = {'markersize': 9}
matplotlib.rc('lines', **markersize)
import numpy as np

# %%
k2orange='#f17e26'
drtcolor1=k2orange
drtcolor2='#d40000'
buscolor='blue'
w=4
h=5

# %%
lo = {'DRT trips': [628.2,926.4,1249,1562.4,1871.6],
      '# DRT vehicles': [17.2,22.8,28.6,36.2,41.2],
      'DRT VKT': [5672.44816,7542.27408,9733.44466,11583.19706,13263.55978],
      'Bus VKT': [3952.85,3952.85,3952.85,3952.85,3999.8],

      'direct km. / drt km.': [0.899401798,1.023260592,1.058135753,1.130339102,1.168454725],
      'direct min. / drt min.': [0.751750296,0.837019531,0.858834165,0.905139127,0.929652706],
      'pass. / vehicle hour': [4.470011329,4.891293355,5.051939332,5.248442469,5.454067837],
      'VKT / vehicle': [329.7934977,330.8014947,340.3302329,319.9778193,321.9310626],
      'VKT / pass.': [9.0290432,8.143164992,7.791740905,7.415550737,7.087981154],
      'direct km / pass.': [8.11815976,8.327359597,8.240362086,8.379533332,8.281177267],
      
#       'bus emissions': [3.6524334,3.6524334,3.6524334,3.6524334,3.6958152],
#       'DRT emissions': [1.260889781,1.715690826,2.207182016,2.661841139,3.030907257],
      
      '# buses': [16,16,16,16,18],

}
lo = pd.DataFrame(lo)

# %%
lo['bus emissions'] = lo['Bus VKT']*806.8425/1000/1000
lo['DRT emissions'] = lo['DRT VKT']*211.118/1000/1000
lo['bus energy'] = lo['Bus VKT']*4.268176891/1000
lo['DRT energy'] = lo['DRT VKT']*0.883/1000

# %%
lo['bus emissions']/lo['DRT emissions']
# Out:
# 0    2.663197
# 1    2.002957
# 2    1.552056
# 3    1.304204
# 4    1.152502
# dtype: float64

# %%
lo['bus energy']/lo['DRT energy']
# Out:
# 0    3.368383
# 1    2.533318
# 2    1.963023
# 3    1.649543
# 4    1.457672
# dtype: float64

# %% [markdown]
# # Demand level

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])
lo['DRT trips'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_yticks(np.linspace(0, 2000, 9))
ax.set_ylim([0,2250])

ax2.set_yticks(np.linspace(0, 40, 5))
ax2.set_ylim([0,45])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors=drtcolor1)

ax2.set_ylabel('Number of DRT vehicles')
ax2.tick_params(axis='y', colors=drtcolor2)

ax2.legend(bbox_to_anchor=(1.25, 1.2))
ax.legend(bbox_to_anchor=(.3, 1.2))

fig.savefig('data/l_t-v_chart.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])
lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['VKT / vehicle'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,25000])

ax.set_xlabel('Demand level')
ax.set_ylabel('Vehicle kilometres travelled')

ax.tick_params(axis='y', colors=drtcolor1)

ax2.set_ylabel('kilometres per vehicle')
ax2.set_ylim([0,800])
ax2.tick_params(axis='y', colors=drtcolor2)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/l_vkt-vktpv_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])
lo['DRT trips'].plot(legend = True, marker='s', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor2, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,2500])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors=drtcolor1)

ax2.set_ylabel('Vehicle kilometres travelled')
ax2.set_ylim([0,25000])
ax2.tick_params(axis='y', colors=drtcolor2)

ax2.legend(bbox_to_anchor=(1.28, 1.15))
ax.legend(bbox_to_anchor=(.30, 1.15))

fig.savefig('data/l_t-vkt_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])
lo['Bus VKT'].plot(legend = True, marker='o', color=buscolor, ax=ax)
lo['DRT VKT'].plot(legend = True, marker='s', color=k2orange, ax=ax)


ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,14000])

ax.set_xlabel('Demand level')
ax.set_ylabel('Vehicle kilometres travelled')

ax.legend(bbox_to_anchor=(.72, 1.18))

fig.savefig('data/l_vkt_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])
lo['bus emissions'].plot( marker='o', color=buscolor, ax=ax)
lo['DRT emissions'].plot( marker='s', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['bus energy'].plot( marker='o', color=buscolor, linestyle='dotted', ax=ax2)
lo['DRT energy'].plot( marker='s', color=drtcolor1, linestyle='dotted', ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,5])
ax2.set_ylim(0,27)
ax.set_xlabel('Demand level')
ax.set_ylabel('CO2 emissions, t')
ax.tick_params(axis='y', colors=buscolor)
ax2.set_ylabel('Energy consumption, GJ')
ax2.tick_params(axis='y', colors=drtcolor1)

handles1, labels1 = ax.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

ax.legend(handles=[handles1[0], handles2[0]], bbox_to_anchor=(.52, 1.20))
ax2.legend(handles=[handles1[1], handles2[1]],bbox_to_anchor=(1.15, 1.20))

fig.savefig('data/l_co2_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = lo['# buses'].plot(legend = True, marker='o', color=buscolor)
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor1, ax=ax)


ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,50])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of vehicles')

ax.legend(bbox_to_anchor=(.93, 1.25))

fig.savefig('data/l_nvehicles_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = lo['# buses'].plot(legend = True, marker='o', color=buscolor)
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['Bus VKT'].plot(legend = True, marker='o', linestyle='dotted', color=buscolor, ax=ax2)
lo['DRT VKT'].plot(legend = True, marker='s', linestyle='dotted', color=k2orange, ax=ax2)

ax2.set_ylim([0,14000])

ax2.set_xlabel('Demand level')
ax2.set_ylabel('Vehicle kilometres travelled')

ax2.legend(bbox_to_anchor=(.72, 1.18))


ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,50])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of vehicles')

handles1, labels1 = ax.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

ax.legend(handles=[handles1[0], handles1[1]], bbox_to_anchor=(.64, 1.30))
ax2.legend(handles=[handles2[0], handles2[1]],bbox_to_anchor=(1.35, 1.30))

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['direct km. / drt km.'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
# lo['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
lo['VKT / pass.'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)
# lo['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')
ax.set_ylabel('Ratio of direct to vehicle kilometres')
ax2.set_ylabel('Ratio of vehicle kilometres per passenger')

ax.tick_params(axis='y', colors=drtcolor1)
ax2.set_ylim([0,16])
ax2.tick_params(axis='y', colors=drtcolor2)

ax2.legend(bbox_to_anchor=(1.20, 1.15))
ax.legend(bbox_to_anchor=(.60, 1.15))

fig.savefig('data/l_vkt-pass_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
df = {'bus Model 1': [244.4890162,168.380829,124.8903122,99.83870968,84.62705706],
      'bus Model 3': [221.8515045,150.4394593,111.5829585,89.20066252,76.04131315],
      'DRT Model 1': [130.14441,117.4982446,110.0074943,110.3217748,105.0353269],
      'DRT Model 2': [185.0953856,166.9348823,159.7306886,152.0187901,145.3036136],
      'DRT Model 3': [129.1121469,117.6472445,112.2347759,109.1134223,104.8191182]
}

df = pd.DataFrame(df)

# %%
df = df*0.094

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

df['bus Model 1'].plot(legend = True, marker='o', color=buscolor, ax=ax)
df['bus Model 3'].plot(legend = True, marker='s', color=buscolor, ax=ax)
df['DRT Model 1'].plot(legend = True, marker='+', color=drtcolor1, ax=ax)
df['DRT Model 2'].plot(legend = True, marker='s', color=drtcolor1, ax=ax)
df['DRT Model 3'].plot(legend = True, marker='x', color=drtcolor1, ax=ax)
# p = df.plot(legend = True, style=['o-b','s-b','+-r','s-r','x-r'], ax=ax)

ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)

ax.set_xlabel('Demand level')
ax.set_ylabel('Cost per trip, EUR')
ax.set_ylim(0,35)
ax.grid(axis="y")
ax.legend()
# plt.legend(bbox_to_anchor=(1.01, 1.1))
fig.savefig('data/cost_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(16, 10)

df['bus Model 1'].plot(marker='o', color=buscolor, ax=axs[0,0])
df['bus Model 3'].plot(marker='s', color=buscolor, ax=axs[0,0])
df['DRT Model 1'].plot(marker='+', color=drtcolor1, ax=axs[0,0])
df['DRT Model 2'].plot(marker='s', color=drtcolor1, ax=axs[0,0])
df['DRT Model 3'].plot(marker='x', color=drtcolor1, ax=axs[0,0])
# p = df.plot(legend = True, style=['o-b','s-b','+-r','s-r','x-r'], ax=ax)
# ax0=axs[0,0].twinx()

axs[0,0].set_xlim(-0.5,4.5)
axs[0,0].set_xticks([0,1,2,3,4])
axs[0,0].set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
axs[0,0].set_xlabel('Demand level')
axs[0,0].set_ylabel('Cost per trip, EUR')
axs[0,0].set_ylim(0,35)
axs[0,0].grid(axis="y")

# handles1, labels1 = axs[0, 1].get_legend_handles_labels()
# axs[0, 1].legend(handles1=[handles1[0], handles1[1]], bbox_to_anchor=(.425, 1.35))
# axs[0, 1].legend(handle1s=[handles1[2], handles1[3]], bbox_to_anchor=(.425, 1.35))
axs[0,0].legend(ncol=3, bbox_to_anchor=(1.1, 1.35))

# axs[0,0].legend()

# *******************************

lo['# buses'].plot(marker='o', color=buscolor, ax=axs[0, 1])
lo['# DRT vehicles'].plot(marker='s', color=drtcolor1, ax=axs[0, 1])
ax1=axs[0, 1].twinx()
lo['Bus VKT'].plot(marker='o', linestyle='dotted', color=buscolor, ax=ax1)
lo['DRT VKT'].plot(marker='s', linestyle='dotted', color=drtcolor1, ax=ax1)

axs[0, 1].grid(axis="y")
axs[0, 1].set_xlim(-0.5,4.5)
axs[0, 1].set_xticks([0,1,2,3,4])
axs[0, 1].set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
axs[0, 1].set_xlabel('Demand level')

axs[0, 1].set_ylim([0,50])
axs[0, 1].set_ylabel('Number of vehicles')

ax1.set_ylim([0,14000])
ax1.set_ylabel('Vehicle kilometres travelled')

handles1, labels1 = axs[0, 1].get_legend_handles_labels()
handles2, labels2 = ax1.get_legend_handles_labels()

axs[0, 1].legend(handles=[handles1[0], handles1[1]], bbox_to_anchor=(.435, 1.35))
# ax1.legend(handles=[h1[0], h2[0]],bbox_to_anchor=(1.01, 1.30))
ax1.legend(handles=[handles2[0], handles2[1]],bbox_to_anchor=(1.02, 1.35))

# *******************************

lo['bus emissions'].plot( marker='o', color=buscolor, ax=axs[1, 0])
lo['DRT emissions'].plot( marker='s', color=drtcolor1, ax=axs[1, 0])
ax2=axs[1, 0].twinx()
lo['bus energy'].plot( marker='o', color=buscolor, linestyle='dotted', ax=ax2)
lo['DRT energy'].plot( marker='s', color=drtcolor1, linestyle='dotted', ax=ax2)

axs[1, 0].grid(axis="y")
axs[1, 0].set_xlim(-0.5,4.5)
axs[1, 0].set_xticks([0,1,2,3,4])
axs[1, 0].set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
axs[1, 0].set_ylim([0,5])
ax2.set_ylim(0,27)
axs[1, 0].set_xlabel('Demand level')
axs[1, 0].set_ylabel('CO2 emissions, t')
axs[1, 0].tick_params(axis='y')
ax2.set_ylabel('Energy consumption, GJ')
ax2.tick_params(axis='y')

handles1, labels1 = axs[1, 0].get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

axs[1, 0].legend(handles=[handles1[0], handles1[1]], bbox_to_anchor=(.42, 1.35))
ax2.legend(handles=[handles2[0], handles2[1]],bbox_to_anchor=(1.02, 1.35))

# # ******************************

lo['direct km. / drt km.'].plot(legend = True, marker='o', color=drtcolor1, ax=axs[1,1])
# lo['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=axs[1,1])
ax3=axs[1,1].twinx()
lo['VKT / pass.'].plot(legend = True, marker='s', color=drtcolor2, ax=ax3)
# lo['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax3)

axs[1,1].grid(axis="y")
axs[1,1].set_xlim(-0.5,4.5)
axs[1,1].set_xticks([0,1,2,3,4])
axs[1,1].set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
axs[1,1].set_ylim([0,1.4])

axs[1,1].set_xlabel('Demand level')
axs[1,1].set_ylabel('Ratio of direct to vehicle kilometres')
ax3.set_ylabel('Ratio of vehicle kilometres per passenger')

axs[1,1].tick_params(axis='y', colors=drtcolor1)
ax3.set_ylim([0,16])
ax3.tick_params(axis='y', colors=drtcolor2)

ax3.legend(bbox_to_anchor=(1.02, 1.25))
axs[1,1].legend(bbox_to_anchor=(.52, 1.25))

fig.tight_layout()
fig.savefig('data/test.eps', bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# # Time windows

# %%
lo = {'DRT trips': [1128.6,1206.4,1223.6,1242.2,1235,1234.8],
      '# DRT vehicles': [30.8,30.8,30.2,28.2,26.8,26],
      'DRT VKT': [9600.83262,9807.04324,9683.5866,9691.76772,9304.58016,9121.62796],
      'DRT+PT trips': [110.8,190.6,208,225.4,220,219],
      'DRT direct trips': [1017.8,1015.8,1015.6,1016.8,1015,1015.8],

      'direct km. / drt km.': [0.986791476,1.01519469,1.044287427,1.057284686,1.094126426,1.115754139],
      'direct km / pass.': [8.393024415,8.247251718,8.262515914,8.247621478,8.242734019,8.241463549],
      
      'DRT Model 1': [128.4499235,120.8655704,117.132057,109.2489358,104.8703239,102.0684607],
      'DRT Model 2': [174.4091548,166.6151755,162.2141849,159.9400478,154.4559265,151.4461874],
      'DRT Model 3': [122.2024552,117.6499066,115.1136416,113.5515854,110.514931,108.6806375]
}
lo = pd.DataFrame(lo)

# %%
lo['DRT Model 1'] = lo['DRT Model 1']*0.094
lo['DRT Model 2'] = lo['DRT Model 2']*0.094
lo['DRT Model 3'] = lo['DRT Model 3']*0.094
lo['DRT emissions'] = lo['DRT VKT']*211.118/1000/1000
lo['DRT energy'] = lo['DRT VKT']*0.883/1000

lo['VKT / pass.'] = lo['DRT VKT']/lo['DRT trips']

# %%
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(16, 10)

lo['DRT Model 1'].plot(legend = True, marker='+', color=drtcolor1,ax=axs[0, 0])
lo['DRT Model 2'].plot(legend = True, marker='s', color=drtcolor1,ax=axs[0, 0])
lo['DRT Model 3'].plot(legend = True, marker='x', color=drtcolor1,ax=axs[0, 0])

axs[0, 0].set_xlim(-0.5,5.5)
axs[0, 0].set_xticks([0,1,2,3,4,5])
axs[0, 0].set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
axs[0, 0].set_xlabel('Time window size, h')
axs[0, 0].set_ylabel('Cost per trip, EUR')
axs[0, 0].grid(axis="y")
axs[0, 0].set_ylim([0,20])
# handles1, labels1 = axs[0, 1].get_legend_handles_labels()
# axs[0, 1].legend(handles1=[handles1[0], handles1[1]], bbox_to_anchor=(.425, 1.35))
# axs[0, 1].legend(handle1s=[handles1[2], handles1[3]], bbox_to_anchor=(.425, 1.35))
axs[0,0].legend(ncol=3, bbox_to_anchor=(1.07, 1.18))

# axs[0,0].legend()

# *******************************

lo['DRT emissions'].plot(legend = True, marker='o', color=drtcolor1, ax=axs[0, 1])
ax1=axs[0, 1].twinx()
lo['DRT energy'].plot(legend = True, marker='s', color=drtcolor2, linestyle='dotted', ax=ax1)

axs[0, 1].grid(axis="y")
axs[0, 1].set_xlim(-0.5,5.5)
axs[0, 1].set_xticks([0,1,2,3,4,5])
axs[0, 1].set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
axs[0, 1].set_xlabel('Time window size, h')
axs[0, 1].set_ylim([0,5])
ax1.set_ylim(0,27)
axs[0, 1].set_ylabel('CO2 emissions, t')
ax1.set_ylabel('Energy consumption, GJ')

axs[0, 1].tick_params(axis='y', colors=drtcolor1)
ax1.tick_params(axis='y', colors=drtcolor2)

axs[0, 1].legend(bbox_to_anchor=(.41, 1.18))
ax1.legend(bbox_to_anchor=(1.02, 1.18))

# *******************************

lo['DRT trips'].plot(legend = True, marker='o', color=drtcolor1,ax=axs[1, 0])
lo['DRT direct trips'].plot(legend = True, marker='s', color=drtcolor1, linestyle='dotted', ax=axs[1, 0])
lo['DRT+PT trips'].plot(legend = True, marker='x', color=drtcolor1, linestyle='dotted', ax=axs[1, 0])


axs[1, 0].set_xlim(-0.5,5.5)
axs[1, 0].set_xticks([0,1,2,3,4,5])
axs[1, 0].set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
axs[1, 0].set_xlabel('Time window size, h')
axs[1, 0].set_ylabel('Number of trips')
axs[1, 0].grid(axis="y")

axs[1, 0].set_ylim([0,1300])
axs[1, 0].legend(bbox_to_anchor=(1.07, 1.18), ncol=3)

# # ******************************

lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor1, ax=axs[1, 1])
ax2=axs[1, 1].twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor2,ax=ax2)


axs[1, 1].grid(axis="y")
axs[1, 1].set_xlim(-0.5,5.5)
axs[1, 1].set_xticks([0,1,2,3,4,5])
axs[1, 1].set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
axs[1, 1].set_xlabel('Time window size, h')
axs[1, 1].set_ylim([0,11000])
axs[1, 1].set_ylabel('Vehicle kilometres travelled')

ax2.set_ylim([0,35])
ax2.tick_params(axis='y', colors=drtcolor2)
ax2.set_ylabel('Number of vehicles')
axs[1, 1].tick_params(axis='y', colors=drtcolor1)

ax2.legend(bbox_to_anchor=(1.02, 1.18))
axs[1, 1].legend(bbox_to_anchor=(.31, 1.18))

fig.tight_layout()
fig.savefig('data/test.eps', bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT Model 1'].plot(legend = True, marker='+', color=drtcolor1, ax=ax)
lo['DRT Model 2'].plot(legend = True, marker='s', color=drtcolor1, ax=ax)
lo['DRT Model 3'].plot(legend = True, marker='x', color=drtcolor1, ax=ax)

ax.set_xlim(-0.5,5.5)
ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
ax.set_xlabel('Time window size, h')
ax.set_ylabel('Cost per trip, EUR')
ax.grid(axis="y")
ax.set_ylim([0,20])
# ax.legend(bbox_to_anchor=(.5, 1.4))
fig.savefig('data/lo_tw_cost_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1.0, 1.0, 1.0, 1.0])

lo['DRT trips'].plot(legend = True, marker='o', color=drtcolor1,ax=ax)
lo['DRT direct trips'].plot(legend = True, marker='s', color=drtcolor1, linestyle='dotted', ax=ax)
lo['DRT+PT trips'].plot(legend = True, marker='x', color=drtcolor1,linestyle='dotted', ax=ax)
ax2=ax.twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)

ax.set_xlim(-0.5,5.5)
ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
ax.set_xlabel('Time window size, h')
ax.set_ylabel('Number of trips')
ax2.set_ylabel('Number of vehicles')
ax.grid(axis="y")
ax2.set_ylim([0,35])
ax.set_ylim([0,1300])
ax.legend(bbox_to_anchor=(0.45, 1.25))
ax2.legend(bbox_to_anchor=(1.15, 1.15))
ax.tick_params(axis='y', colors=drtcolor1)
ax2.tick_params(axis='y', colors=drtcolor2)
fig.savefig('data/lo_tw_trips_vehicles.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT emissions'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['DRT energy'].plot(legend = True, marker='s', color=drtcolor2, linestyle='dotted', ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,5.5)
ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
ax.set_xlabel('Time window size, h')
ax.set_ylim([0,5])
ax2.set_ylim(0,27)
ax.set_ylabel('CO2 emissions, t')
ax2.set_ylabel('Energy consumption, GJ')

ax.tick_params(axis='y', colors=drtcolor1)
ax2.tick_params(axis='y', colors=drtcolor2)

ax.legend(bbox_to_anchor=(.52, 1.15))
ax2.legend(bbox_to_anchor=(1.15, 1.15))

fig.savefig('data/lo_tw_co2_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['VKT / pass.'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,5.5)
ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(['0.25', '0.5', '0.75', '1.0', '1.25', '1.5'])
ax.set_xlabel('Time window size, h')
ax.set_ylim([0,11000])

ax2.set_ylim([0,10])
ax2.tick_params(axis='y', colors=drtcolor2)
ax.tick_params(axis='y', colors=drtcolor1)

ax2.legend(bbox_to_anchor=(1.08, 1.2))
ax.legend(bbox_to_anchor=(.35, 1.2))

fig.savefig('data/lo_tw_vkt-pass_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
lo = {'DRT trips': [1147,1208.8,1219,1227.8,1232.6],
      '# DRT vehicles': [29,30.6,27,27.2,26.8],
      'DRT VKT': [9795.38484,9941.26162,9443.49176,9348.03258,9216.24666],
      'DRT+PT trips': [128.4,190.8,201.6,209.8,214.6],
      'DRT direct trips': [1018.6,1018,1017.4,1018,1018],
      
      'DRT Model 1': [120.8397312,120.2978078,107.0378071,106.7184874,104.87529],
      'DRT Model 2': [175.0322596,168.5782204,158.8010151,156.059463,153.2591692],
      'DRT Model 3': [122.5940559,118.7807546,113.0765901,111.2335978,109.6417017]
}
lo = pd.DataFrame(lo)

# %%
lo['DRT Model 1'] = lo['DRT Model 1']*0.094
lo['DRT Model 2'] = lo['DRT Model 2']*0.094
lo['DRT Model 3'] = lo['DRT Model 3']*0.094
lo['DRT emissions'] = lo['DRT VKT']*211.118/1000/1000
lo['DRT energy'] = lo['DRT VKT']*0.883/1000

lo['VKT / pass.'] = lo['DRT VKT']/lo['DRT trips']

# %%
lo['DRT emissions']
# Out:
# 0    2.067982
# 1    2.098779
# 2    1.993691
# 3    1.973538
# 4    1.945716
# Name: DRT emissions, dtype: float64

# %%
2.098779/1.945716
# Out:
# 1.0786666707782635

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT Model 1'].plot(legend = True, marker='+', color=drtcolor1,ax=ax)
lo['DRT Model 2'].plot(legend = True, marker='s', color=drtcolor1,ax=ax)
lo['DRT Model 3'].plot(legend = True, marker='x', color=drtcolor1,ax=ax)

ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
ax.set_xlabel('Direct trip multiplier')
ax.set_ylabel('Cost per trip, EUR')
ax.grid(axis="y")
ax.set_ylim([0,20])
# ax.legend(bbox_to_anchor=(.5, 1.4))
fig.savefig('data/lo_dtm_cost_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT trips'].plot(legend = True, marker='o', color=drtcolor1,ax=ax)
lo['DRT direct trips'].plot(legend = True, marker='s', color=drtcolor1, linestyle='dotted', ax=ax)
lo['DRT+PT trips'].plot(legend = True, marker='x', color=drtcolor1, linestyle='dotted', ax=ax)
ax2=ax.twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor2,ax=ax2)

ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
ax.set_xlabel('Direct trip multiplier')
ax.set_ylabel('Number of trips')
ax.grid(axis="y")
ax2.set_ylim([0,35])
ax.set_ylim([0,1300])
ax.legend(bbox_to_anchor=(0.45, 1.25))
ax2.legend(bbox_to_anchor=(1.15, 1.15))
ax.tick_params(axis='y', colors=drtcolor1)
ax2.tick_params(axis='y', colors=drtcolor2)
fig.savefig('data/lo_dtm_trips_vehicles.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT emissions'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
ax2=ax.twinx()
lo['DRT energy'].plot(legend = True, marker='s', color=drtcolor2, linestyle='dotted', ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
ax.set_xlabel('Direct trip multiplier')
ax.set_ylim([0,5])
ax2.set_ylim(0,27)
ax.set_ylabel('CO2 emissions, t')
ax2.set_ylabel('Energy consumption, GJ')

ax.tick_params(axis='y', colors=drtcolor1)
ax2.tick_params(axis='y', colors=drtcolor2)

ax.legend(bbox_to_anchor=(.52, 1.25))
ax2.legend(bbox_to_anchor=(1.32, 1.25))

fig.savefig('data/lo_dtm_co2_chart.eps',bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor1, ax=ax)
# lo['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
lo['VKT / pass.'].plot(legend = True, marker='s', color=drtcolor2, ax=ax2)
# lo['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
ax.set_xlabel('Direct trip multiplier')
ax.set_ylim([0,11000])

ax2.set_ylim([0,10])
ax2.tick_params(axis='y', colors=drtcolor2)
ax.tick_params(axis='y', colors=drtcolor1)

ax2.legend(bbox_to_anchor=(1.08, 1.2))
ax.legend(bbox_to_anchor=(.35, 1.2))

fig.savefig('data/lo_dtm_vkt-pass_chart.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(16, 10)

lo['DRT Model 1'].plot(legend = True, marker='+', color=drtcolor1,ax=axs[0, 0])
lo['DRT Model 2'].plot(legend = True, marker='s', color=drtcolor1,ax=axs[0, 0])
lo['DRT Model 3'].plot(legend = True, marker='x', color=drtcolor1,ax=axs[0, 0])

axs[0, 0].set_xlim(-0.5,4.5)
axs[0, 0].set_xticks([0,1,2,3,4])
axs[0, 0].set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
axs[0, 0].set_xlabel('Direct trip multiplier')
axs[0, 0].set_ylabel('Cost per trip, EUR')
axs[0, 0].grid(axis="y")
axs[0, 0].set_ylim([0,20])
# handles1, labels1 = axs[0, 1].get_legend_handles_labels()
# axs[0, 1].legend(handles1=[handles1[0], handles1[1]], bbox_to_anchor=(.425, 1.35))
# axs[0, 1].legend(handle1s=[handles1[2], handles1[3]], bbox_to_anchor=(.425, 1.35))
axs[0,0].legend(ncol=3, bbox_to_anchor=(1.07, 1.18))

# axs[0,0].legend()

# *******************************

lo['DRT emissions'].plot(legend = True, marker='o', color=drtcolor1, ax=axs[0, 1])
ax1=axs[0, 1].twinx()
lo['DRT energy'].plot(legend = True, marker='s', color=drtcolor2, linestyle='dotted', ax=ax1)

axs[0, 1].grid(axis="y")
axs[0, 1].set_xlim(-0.5,4.5)
axs[0, 1].set_xticks([0,1,2,3,4])
axs[0, 1].set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
axs[0, 1].set_xlabel('Direct trip multiplier')
axs[0, 1].set_ylim([0,5])
ax1.set_ylim(0,27)
axs[0, 1].set_ylabel('CO2 emissions, t')
ax1.set_ylabel('Energy consumption, GJ')

axs[0, 1].tick_params(axis='y', colors=drtcolor1)
ax1.tick_params(axis='y', colors=drtcolor2)

axs[0, 1].legend(bbox_to_anchor=(.41, 1.18))
ax1.legend(bbox_to_anchor=(1.02, 1.18))

# *******************************

lo['DRT trips'].plot(legend = True, marker='o', color=drtcolor1,ax=axs[1, 0])
lo['DRT direct trips'].plot(legend = True, marker='s', color=drtcolor1, linestyle='dotted', ax=axs[1, 0])
lo['DRT+PT trips'].plot(legend = True, marker='x', color=drtcolor1, linestyle='dotted', ax=axs[1, 0])


axs[1, 0].set_xlim(-0.5,4.5)
axs[1, 0].set_xticks([0,1,2,3,4])
axs[1, 0].set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
axs[1, 0].set_xlabel('Direct trip multiplier')
axs[1, 0].set_ylabel('Number of trips')
axs[1, 0].grid(axis="y")

axs[1, 0].set_ylim([0,1300])
axs[1, 0].legend(bbox_to_anchor=(1.07, 1.18), ncol=3)

# # ******************************

lo['DRT VKT'].plot(legend = True, marker='o', color=drtcolor1, ax=axs[1, 1])
ax2=axs[1, 1].twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=drtcolor2,ax=ax2)


axs[1, 1].grid(axis="y")
axs[1, 1].set_xlim(-0.5,4.5)
axs[1, 1].set_xticks([0,1,2,3,4])
axs[1, 1].set_xticklabels(['1.1', '1.3', '1.5', '1.7', '1.9'])
axs[1, 1].set_xlabel('Direct trip multiplier')
axs[1, 1].set_ylim([0,11000])
axs[1, 1].set_ylabel('Vehicle kilometres travelled')

ax2.set_ylim([0,35])
ax2.tick_params(axis='y', colors=drtcolor2)
ax2.set_ylabel('Number of vehicles')
axs[1, 1].tick_params(axis='y', colors=drtcolor1)

ax2.legend(bbox_to_anchor=(1.02, 1.18))
axs[1, 1].legend(bbox_to_anchor=(.31, 1.18))

fig.tight_layout()
fig.savefig('data/test.eps', bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
b_bar = [105737.0,  105647.8,  77674.8,  56084.2,  40170.6,  25256.2,  16652.8,  12273.6,  6871.6,  5907.0,  3680.6,  3443.2,  2182.8,  1707.0,  1381.8,  10635.400000000001,  1188.4,  836.4,  445.4,  234.0,  3297.9999999999995,  444.8,  55.2,  42.0,  54.4,  407.8,  13.0,  23.6,  180.0,  270.6,  66.0,  95.8,  77.8,  108.4,  227.4,  120.4,  191.6,  66.6,  0.6,  167.8,  0.2,  0.2,  0.2,  0.0,  0.2,  0.0,  0.0,  0.0,  0.2,  0.0,  0.0]
total_t_b = 471509.99999999994
drt_bar = [0.256314883004076, 0.3256942919930384, 0.21252882746071658, 0.1140718745827232, 0.05933534456029494, 0.019415959606475457, 0.00839645764541601, 0.002858416713250787, 0.0013839444340085956]

b_per_hour_y = [  0.,   0.,   0.,   0.,   0.,   4.,  54., 176.,  81.,  77.,  89., 84., 112., 116., 116., 143.,  76.,  55.,  39.,  18.,   5.,   0.,  0.,   1.]
b_per_hour_x = [    0.,  3600.,  7200., 10800., 14400., 18000., 21600., 25200., 28800., 32400., 36000., 39600., 43200., 46800., 50400., 54000.,        57600., 61200., 64800., 68400., 72000., 75600., 79200., 82800.]

drt_per_hour_y = [  0.,   0.,   0.,   0.,   0.,   8.,  43., 134., 121.,  81.,  86.,         87., 113., 112., 121., 115., 103.,  68.,  32.,  14.,   6.,   1.,          0.,   1.]
drt_per_hour_x = [    0.,  3600.,  7200., 10800., 14400., 18000., 21600., 25200.,        28800., 32400., 36000., 39600., 43200., 46800., 50400., 54000.,        57600., 61200., 64800., 68400., 72000., 75600., 79200., 82800.]

# %%
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(16, 10)


axs[0,0].bar([str(i) for i in range(0,51)], [i/total_t_b for i in b_bar], color='blue')
axs[0,0].set_ylabel('Proportion of time')
axs[0,0].set_xlabel('Number of passengers in a bus')
# ax.set_title('Vehicle occupancy')
# ax.ylim(0, 12500/60/60*10)
axs[0,0].set_xlim(-0.6, 15.6)
axs[0,0].set_ylim(0, 0.34)
axs[0,0].set_xticklabels([str(i) for i in range(0,15)]+['15+'])

axs[0,1].bar([str(i) for i in range(0,8+1)], [i for i in drt_bar], color='blue')
axs[0,1].set_xlabel('Number of passengers')
axs[0,1].set_ylabel('Proportion of time')
axs[0,1].set_ylim(0, 0.34)

axs[1,0].bar([str(i) for i in b_per_hour_x], b_per_hour_y, color='blue')
axs[1,0].set_ylabel('Passengers per hour')
secaxy = axs[1,0].secondary_yaxis('right', functions=(lambda x: x/16, lambda x: x*16))
secaxy.set_ylabel('Passenger per vehicle per hour')
# plt.title('Distribution of passengers per hour')
axs[1,0].set_xticks([x for x in [0, 3, 6, 9, 12, 15, 18, 21, 24]])
names_x = ['00:00','03:00','6:00','9:00','12:00','15:00','18:00','21:00', '24:00']
axs[1,0].set_xlabel('Time of day')
axs[1,0].set_xticklabels(names_x,rotation=45)
axs[1,0].set_ylim(0,200)
axs[1,0].set_xlim(3,24)

axs[1,1].bar([str(i) for i in drt_per_hour_x], drt_per_hour_y, color='blue')
axs[1,1].set_ylabel('Passengers per hour')
secaxy = axs[1,1].secondary_yaxis('right', functions=(lambda x: x/32, lambda x: x*32))
secaxy.set_ylabel('Passenger per vehicle per hour')
# plt.title('Distribution of passengers per hour')
axs[1,1].set_xticks([x for x in [0, 3, 6, 9, 12, 15, 18, 21, 24]])
names_x = ['00:00','03:00','6:00','9:00','12:00','15:00','18:00','21:00', '24:00']
axs[1,1].set_xlabel('Time of day')
axs[1,1].set_xticklabels(names_x,rotation=45)
axs[1,1].set_ylim(0,200)
axs[1,1].set_xlim(3,24)

fig.tight_layout()
fig.savefig('data/test.eps', bbox_inches="tight")

extent = axs[0,0].get_tightbbox(fig.canvas.renderer).transformed(fig.dpi_scale_trans.inverted())
fig.savefig('data/ax0_figure.eps', bbox_inches=extent)
