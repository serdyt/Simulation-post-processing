# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
font = {'size': 16}
matplotlib.rc('font', **font)
import numpy as np

# %%
k2orange='#f17e26'
w=4
h=5

# %%
sj = {'DRT trips': [694,1091,1328,1462,1551],
      '# DRT vehicles': [30]*5,
      'VKT': [11007,15825,19297,21578,22383],
      'direct km. / drt km.': [0.804017443,0.952726698,0.974244701,0.982879322,1.025314381],
      'direct min. / drt min.': [0.691728536,0.801602808,0.818164697,0.829564049,0.859525181],
      'pass. / vehicle hour': [2.407715792,2.599599695,2.596204224,2.563113604,2.614852904],    
      'VKT / vehicle': [366.9,527.5,643.2333333,719.2666667,746.1],
      'VKT / pass.': [15.86023055,14.50504125,14.53087349,14.75923393,14.43133462],
      'direct km / pass.': [12.75190202,13.81934005,14.15662651,14.50654583,14.79665493],
}
sj = pd.DataFrame(sj)

sj_o = {
      'DRT trips': [634,1093,1350,1537,1669],
      '# DRT vehicles': [30]*5,
      'VKT': [9848.1094,14309.0152,17131.6329,18582.991,20213.6952],
      'direct km. / drt km.': [0.508519524,0.489688368,0.495304776,0.483878462,0.530215702],
      'direct min. / drt min.': [0.57 ,0.53 ,0.53 ,0.52 ,0.57 ],
      'pass. / vehicle hour': [2.646788693,3.032474949,3.10571906,3.227031198,3.230661279],
      'VKT / vehicle': [328.2703133,476.9671733,571.05443,619.4330333,673.78984],
      'VKT / pass.': [15.53329558,13.09150522,12.69009844,12.09043006,12.11126135],
      'direct km / pass.': [7.898984069,6.410757823,6.28546637,5.850298699,6.421580947],
    
}
sj_o = pd.DataFrame(sj_o)


lo = {'DRT trips': [585.4,866.4,1162.6,1464.4,1752.75],
      '# DRT vehicles': [18.4,23,27.4,34.4,42.5],
      'VKT': [4874.888,6633.25276,8533.47,10291.28606,11718.18],
      'direct km. / drt km.': [0.959506601,1.072136381,1.10794291,1.172222792,1.220177115],
      'direct min. / drt min.': [0.790357936,0.867147875,0.888431204,0.927914606,0.956198572],
      'pass. / vehicle hour': [4.754357944,5.124030848,5.273249758,5.4514115,5.670486744],
      'VKT / vehicle': [264.9395652,288.4022939,311.4405109,299.1652924,275.7218824],
      'VKT / pass.': [8.327447899,7.65610891,7.339987958,7.027646857,6.685596919],
      'direct km / pass.': [7.990241225,8.208392896,8.13228762,8.237967821,8.157612362],
}
lo = pd.DataFrame(lo)

# %% [markdown]
# # Trips to vehicles

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj['# DRT vehicles'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")

ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_yticks(np.linspace(0, 2000, 9))
ax.set_ylim([0,2250])

ax2.set_yticks(np.linspace(0, 40, 5))
ax2.set_ylim([0,45])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Number of DRT vehicles')
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.25, 1.2))
ax.legend(bbox_to_anchor=(.3, 1.2))

fig.savefig('data/s t-v_chart.svg',  bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj_o['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj_o['# DRT vehicles'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")

ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_yticks(np.linspace(0, 2000, 9))
ax.set_ylim([0,2250])

ax2.set_yticks(np.linspace(0, 40, 5))
ax2.set_ylim([0,45])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Number of DRT vehicles')
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.25, 1.2))
ax.legend(bbox_to_anchor=(.3, 1.2))

fig.savefig('data/so t-v_chart.svg',  bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = lo['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
lo['# DRT vehicles'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_yticks(np.linspace(0, 2000, 9))
ax.set_ylim([0,2250])

ax2.set_yticks(np.linspace(0, 40, 5))
ax2.set_ylim([0,45])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Number of DRT vehicles')
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.25, 1.2))
ax.legend(bbox_to_anchor=(.3, 1.2))

fig.savefig('data/l t-v_chart.svg',  bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj['VKT'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj['VKT / vehicle'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,25000])

ax.set_xlabel('Demand level')
ax.set_ylabel('Vehicle kilometres travelled')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('kilometres per vehicle')
ax2.set_ylim([0,800])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/s vkt-vktpv_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj_o['VKT'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj_o['VKT / vehicle'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,25000])

ax.set_xlabel('Demand level')
ax.set_ylabel('Vehicle kilometres travelled')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('kilometres per vehicle')
ax2.set_ylim([0,800])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/so vkt-vktpv_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = lo['VKT'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
lo['VKT / vehicle'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,25000])

ax.set_xlabel('Demand level')
ax.set_ylabel('Vehicle kilometres travelled')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('kilometres per vehicle')
ax2.set_ylim([0,800])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/l vkt-vktpv_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj['VKT'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,2500])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Vehicle kilometres travelled')
ax2.set_ylim([0,25000])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/s t-vkt_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = sj_o['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
sj_o['VKT'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,2500])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Vehicle kilometres travelled')
ax2.set_ylim([0,25000])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/so t-vkt_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = lo['DRT trips'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'])
ax2=ax.twinx()
lo['VKT'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,2500])

ax.set_xlabel('Demand level')
ax.set_ylabel('Number of trips')

ax.tick_params(axis='y', colors='b')

ax2.set_ylabel('Vehicle kilometres travelled')
ax2.set_ylim([0,25000])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/l t-vkt_chart.svg',bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

sj['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
sj['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
sj['pass. / vehicle hour'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,6])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/s d-a_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

sj_o['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
sj_o['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
sj_o['pass. / vehicle hour'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,6])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/so d-a_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
lo['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
lo['pass. / vehicle hour'].plot(legend = True, marker='s', color=k2orange, ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,6])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/l d-a_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

sj['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
# sj['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
sj['VKT / pass.'].plot(legend = True, marker='s', color=k2orange, ax=ax2)
sj['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,16])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/s vkt-pass_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

sj_o['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
# sj_o['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
sj_o['VKT / pass.'].plot(legend = True, marker='s', color=k2orange, ax=ax2)
sj_o['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['20%', '40%', '60%', '80%', '100%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,16])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/so vkt-pass_chart.svg', bbox_inches='tight')

# %%
fig = plt.figure(edgecolor="black", linewidth=1, figsize=(w,h))

ax = fig.add_axes([1., 1., 1., 1.])

lo['direct km. / drt km.'].plot(legend = True, style=['o-b','s-b','o-r','x-r','s-r'], ax=ax)
# lo['direct min. / drt min.'].plot(legend = True, marker='x', color='g',ax=ax)
ax2=ax.twinx()
lo['VKT / pass.'].plot(legend = True, marker='s', color=k2orange, ax=ax2)
lo['direct km / pass.'].plot(legend = True, marker='s', color="r", ax=ax2)

ax.grid(axis="y")
ax.set_xlim(-0.5,4.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(['50%', '75%', '100%', '125%', '150%'], rotation=45,)
ax.set_ylim([0,1.4])

ax.set_xlabel('Demand level')

ax2.set_ylim([0,16])
ax2.tick_params(axis='y', colors=k2orange)

ax2.legend(bbox_to_anchor=(1.3, 1.2))
ax.legend(bbox_to_anchor=(.4, 1.2))

fig.savefig('data/l vkt-pass_chart.svg', bbox_inches='tight')

# %% [markdown]
# # Costs

# %%
df = {
      'DRT Model 1': [223.9398496,142.0755046,121.0840608,109.3327503,103.3457377],
      'DRT Model 2': [318.4325595,268.3758569,260.1470181,247.8538162,248.2808578],
      'DRT Model 3': [218.9932761,188.3913523,183.2277651,175.7861889,175.5486858]
}

df = pd.DataFrame(df)
df = df*0.094

# %%
plt = df.plot(legend = True, style=['o-r','x-r','s-r'])
plt.set_xlim(-0.5,4.5)
plt.set_xticks([0,1,2,3,4])
plt.set_xticklabels(['20%', '40%', '60%', '80%', '100%'])
plt.set_xlabel('Demand level')
plt.set_ylabel('Cost per trip, EUR')
plt.grid(axis="y")
plt.set_ylim([0,30])
plt.legend(bbox_to_anchor=(.5, 1.4))
fig = plt.get_figure()
fig.savefig('data/sjöbo_outside_cost_chart.svg', bbox_inches='tight')

# %%
df = {
      'DRT Model 1': [212.3054755,148.3143905,129.4600791,122.0291944,116.6415216],
      'DRT Model 2': [325.1347262,297.3533456,297.8829066,302.5642955,295.8423598],
      'DRT Model 3': [136.8851058,122.6072715,119.2506418,119.0902236,114.9794633]
}

df = pd.DataFrame(df)
df = df*0.094

# %%
plt = df.plot(legend = True, style=['o-r','x-r','s-r'])
plt.set_xlim(-0.5,4.5)
plt.set_xticks([0,1,2,3,4])
plt.set_xticklabels(['20%', '40%', '60%', '80%', '100%'])
plt.set_xlabel('Demand level')
plt.set_ylabel('Cost per trip, EUR')
plt.grid(axis="y")
plt.set_ylim([0,30])
plt.legend(bbox_to_anchor=(.5, 1.4))
fig = plt.get_figure()
fig.savefig('data/sjöbo_within_cost_chart.svg', bbox_inches='tight')
